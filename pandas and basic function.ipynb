# %%
import pandas as pd

# %%
dict1 = {"name" :["ineuron" , "sudh" , "krish" , "kumar"],
         "number":[3,4,6,9],
         "test":["xyz" ,"ABC" ,"dyu" , "ert"],
         "string" :["dfdsfs" ,"dsfsf" ,"trert" ,"rwewer"]
    }

# %%
df1 = pd.DataFrame(dict1)

# %%
df1
# Out:
#       name  number test  string
# 0  ineuron       3  xyz  dfdsfs
# 1     sudh       4  ABC   dsfsf
# 2    krish       6  dyu   trert
# 3    kumar       9  ert  rwewer

# %%
dict2 = {"name1" :["ineuron1" , "sudh1" , "krish" , "kumar"],
         "number1":[31,41,61,91],
         "test1":["xyz1" ,"ABC1" ,"dyu1" , "ert1"],
         "string1" :["dfdsfs" ,"dsfsf" ,"trert1" ,"rwewer"]
    }

# %%
df2 = pd.DataFrame(dict2)

# %%
df2
# Out:
#       name1  number1 test1 string1
# 0  ineuron1       31  xyz1  dfdsfs
# 1     sudh1       41  ABC1   dsfsf
# 2     krish       61  dyu1  trert1
# 3     kumar       91  ert1  rwewer

# %%
df3 = pd.concat([df1,df2])

# %%
"sudh" + " kumar"
# Out:
# 'sudh kumar'

# %%
df4 = pd.concat([df1,df2] ,axis= 1)

# %%
df3
# Out:
#       name  number test  string     name1  number1 test1 string1
# 0  ineuron     3.0  xyz  dfdsfs       NaN      NaN   NaN     NaN
# 1     sudh     4.0  ABC   dsfsf       NaN      NaN   NaN     NaN
# 2    krish     6.0  dyu   trert       NaN      NaN   NaN     NaN
# 3    kumar     9.0  ert  rwewer       NaN      NaN   NaN     NaN
# 0      NaN     NaN  NaN     NaN  ineuron1     31.0  xyz1  dfdsfs
# 1      NaN     NaN  NaN     NaN     sudh1     41.0  ABC1   dsfsf
# 2      NaN     NaN  NaN     NaN     krish     61.0  dyu1  trert1
# 3      NaN     NaN  NaN     NaN     kumar     91.0  ert1  rwewer

# %%
df4
# Out:
#       name  number test  string     name1  number1 test1 string1
# 0  ineuron       3  xyz  dfdsfs  ineuron1       31  xyz1  dfdsfs
# 1     sudh       4  ABC   dsfsf     sudh1       41  ABC1   dsfsf
# 2    krish       6  dyu   trert     krish       61  dyu1  trert1
# 3    kumar       9  ert  rwewer     kumar       91  ert1  rwewer

# %%
df4.iloc[1:3,1:3]
# Out:
#    number test
# 1       4  ABC
# 2       6  dyu

# %%
df4.iloc[[1,3],5:]
# Out:
#    number1 test1 string1
# 1       41  ABC1   dsfsf
# 3       91  ert1  rwewer

# %%
df5 = df4.iloc[[1,3]]

# %%
df5[['number1', 'test1','string1']]
# Out:
#    number1 test1 string1
# 1       41  ABC1   dsfsf
# 3       91  ert1  rwewer

# %%
df4.columns
# Out:
# Index(['name', 'number', 'test', 'string', 'name1', 'number1', 'test1',
#        'string1'],
#       dtype='object')

# %%
dict1 = {"name" :["ineuron" , "sudh" , "krish" , "kumar"],
         "number":[3,4,6,9],
         "test":["xyz" ,"ABC" ,"dyu" , "ert"],
         "string" :["dfdsfs" ,"dsfsf" ,"trert" ,"rwewer"]
    }

# %%
dict2 = {"name" :["ineuron1" , "sudh1" , "krish" , "kumar"],
         "number":[31,41,61,91],
         "test":["xyz1" ,"ABC1" ,"dyu1" , "ert1"],
         "string1" :["dfdsfs" ,"dsfsf" ,"trert1" ,"rwewer"]
    }

# %%
df1 = pd.DataFrame(dict1)

# %%
df2 = pd.DataFrame(dict2)

# %%
df1
# Out:
#       name  number test  string
# 0  ineuron       3  xyz  dfdsfs
# 1     sudh       4  ABC   dsfsf
# 2    krish       6  dyu   trert
# 3    kumar       9  ert  rwewer

# %%
df2
# Out:
#        name  number  test  string
# 0  ineuron1      31  xyz1  dfdsfs
# 1     sudh1      41  ABC1   dsfsf
# 2     krish      61  dyu1  trert1
# 3     kumar      91  ert1  rwewer

# %%
pd.merge(df1 , df2 , on = 'string', how = 'right')
# Out:
#     name_x  number_x test_x  string    name_y  number_y test_y
# 0  ineuron       3.0    xyz  dfdsfs  ineuron1        31   xyz1
# 1     sudh       4.0    ABC   dsfsf     sudh1        41   ABC1
# 2      NaN       NaN    NaN  trert1     krish        61   dyu1
# 3    kumar       9.0    ert  rwewer     kumar        91   ert1

# %%
pd.merge(df1 , df2 , on = 'string')
# Out:
#     name_x  number_x test_x  string    name_y  number_y test_y
# 0  ineuron         3    xyz  dfdsfs  ineuron1        31   xyz1
# 1     sudh         4    ABC   dsfsf     sudh1        41   ABC1
# 2    kumar         9    ert  rwewer     kumar        91   ert1

# %%
pd.merge(df1 , df2 , on = 'string', how = 'left')
# Out:
#     name_x  number_x test_x  string    name_y  number_y test_y
# 0  ineuron         3    xyz  dfdsfs  ineuron1      31.0   xyz1
# 1     sudh         4    ABC   dsfsf     sudh1      41.0   ABC1
# 2    krish         6    dyu   trert       NaN       NaN    NaN
# 3    kumar         9    ert  rwewer     kumar      91.0   ert1

# %%
df1
# Out:
#       name  number test  string
# 0  ineuron       3  xyz  dfdsfs
# 1     sudh       4  ABC   dsfsf
# 2    krish       6  dyu   trert
# 3    kumar       9  ert  rwewer

# %%
df2
# Out:
#        name  number  test string1
# 0  ineuron1      31  xyz1  dfdsfs
# 1     sudh1      41  ABC1   dsfsf
# 2     krish      61  dyu1  trert1
# 3     kumar      91  ert1  rwewer

# %%
pd.merge(df1 , df2 , left_on = 'string',right_on='string1', how = 'outer')
# Out:
#     name_x  number_x test_x  string    name_y  number_y test_y string1
# 0  ineuron       3.0    xyz  dfdsfs  ineuron1      31.0   xyz1  dfdsfs
# 1     sudh       4.0    ABC   dsfsf     sudh1      41.0   ABC1   dsfsf
# 2    krish       6.0    dyu   trert       NaN       NaN    NaN     NaN
# 3    kumar       9.0    ert  rwewer     kumar      91.0   ert1  rwewer
# 4      NaN       NaN    NaN     NaN     krish      61.0   dyu1  trert1

# %%
df1
# Out:
#       name  number test  string
# 0  ineuron       3  xyz  dfdsfs
# 1     sudh       4  ABC   dsfsf
# 2    krish       6  dyu   trert
# 3    kumar       9  ert  rwewer

# %%
df2
# Out:
#        name  number  test string1
# 0  ineuron1      31  xyz1  dfdsfs
# 1     sudh1      41  ABC1   dsfsf
# 2     krish      61  dyu1  trert1
# 3     kumar      91  ert1  rwewer

# %%
pd.merge(df1,df2,how='left' , on = ['name' ,'number'])
# Out:
#       name  number test_x  string test_y string1
# 0  ineuron       3    xyz  dfdsfs    NaN     NaN
# 1     sudh       4    ABC   dsfsf    NaN     NaN
# 2    krish       6    dyu   trert    NaN     NaN
# 3    kumar       9    ert  rwewer    NaN     NaN

# %%
df1
# Out:
#       name  number test  string
# 0  ineuron       3  xyz  dfdsfs
# 1     sudh       4  ABC   dsfsf
# 2    krish       6  dyu   trert
# 3    kumar       9  ert  rwewer

# %%
df2
# Out:
#        name  number  test string1
# 0  ineuron1      31  xyz1  dfdsfs
# 1     sudh1      41  ABC1   dsfsf
# 2     krish      61  dyu1  trert1
# 3     kumar      91  ert1  rwewer

# %%
df1.join(df2 , on = 'name')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-8e0c632786b9> in <module>
# ----> 1 df1.join(df2 , on = 'name')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7868         5  K5  A5  NaN
#    7869         """
# -> 7870         return self._join_compat(
#    7871             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7872         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7884
#    7885         if isinstance(other, DataFrame):
# -> 7886             return merge(
#    7887                 self,
#    7888                 other,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     654         # validate the merge keys dtypes. We may need to coerce
#     655         # to avoid incompatible dtypes
# --> 656         self._maybe_coerce_merge_keys()
#     657
#     658         # If argument passed to validate,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1163                     inferred_right in string_types and inferred_left not in string_types
#    1164                 ):
# -> 1165                     raise ValueError(msg)
#    1166
#    1167             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
dict2 = {"name1" :["ineuron1" , "sudh1" , "krish" , "kumar"],
         "number1":[31,41,61,91],
         "test1":["xyz1" ,"ABC1" ,"dyu1" , "ert1"],
         "string1" :["dfdsfs" ,"dsfsf" ,"trert1" ,"rwewer"]
    }

# %%
df3 = pd.DataFrame(dict2)

# %%
df1.join(df3)
# Out:
#       name  number test  string     name1  number1 test1 string1
# 0  ineuron       3  xyz  dfdsfs  ineuron1       31  xyz1  dfdsfs
# 1     sudh       4  ABC   dsfsf     sudh1       41  ABC1   dsfsf
# 2    krish       6  dyu   trert     krish       61  dyu1  trert1
# 3    kumar       9  ert  rwewer     kumar       91  ert1  rwewer

# %%
df1.join(df3,how = 'outer')
# Out:
#       name  number test  string     name1  number1 test1 string1
# 0  ineuron       3  xyz  dfdsfs  ineuron1       31  xyz1  dfdsfs
# 1     sudh       4  ABC   dsfsf     sudh1       41  ABC1   dsfsf
# 2    krish       6  dyu   trert     krish       61  dyu1  trert1
# 3    kumar       9  ert  rwewer     kumar       91  ert1  rwewer

# %%
df1.join(df3,how = 'left')
# Out:
#       name  number test  string     name1  number1 test1 string1
# 0  ineuron       3  xyz  dfdsfs  ineuron1       31  xyz1  dfdsfs
# 1     sudh       4  ABC   dsfsf     sudh1       41  ABC1   dsfsf
# 2    krish       6  dyu   trert     krish       61  dyu1  trert1
# 3    kumar       9  ert  rwewer     kumar       91  ert1  rwewer

# %%
df1.join(df3,how = 'right')
# Out:
#       name  number test  string     name1  number1 test1 string1
# 0  ineuron       3  xyz  dfdsfs  ineuron1       31  xyz1  dfdsfs
# 1     sudh       4  ABC   dsfsf     sudh1       41  ABC1   dsfsf
# 2    krish       6  dyu   trert     krish       61  dyu1  trert1
# 3    kumar       9  ert  rwewer     kumar       91  ert1  rwewer

# %%
dict2 = {"name1" :["ineuron1" , "sudh1" , "krish" , "kumar"],
         "number1":[31,41,61,91],
         "test1":["xyz1" ,"ABC1" ,"dyu1" , "ert1"],
         "string1" :["dfdsfs" ,"dsfsf" ,"trert1" ,"rwewer"]
    }

# %%
df5 = pd.DataFrame(dict2 , index = [1,0,6,7])

# %%
df1
# Out:
#       name  number test  string
# 0  ineuron       3  xyz  dfdsfs
# 1     sudh       4  ABC   dsfsf
# 2    krish       6  dyu   trert
# 3    kumar       9  ert  rwewer

# %%
df5
# Out:
#       name1  number1 test1 string1
# 1  ineuron1       31  xyz1  dfdsfs
# 0     sudh1       41  ABC1   dsfsf
# 6     krish       61  dyu1  trert1
# 7     kumar       91  ert1  rwewer

# %%
df1.join(df5)
# Out:
#       name  number test  string     name1  number1 test1 string1
# 0  ineuron       3  xyz  dfdsfs     sudh1     41.0  ABC1   dsfsf
# 1     sudh       4  ABC   dsfsf  ineuron1     31.0  xyz1  dfdsfs
# 2    krish       6  dyu   trert       NaN      NaN   NaN     NaN
# 3    kumar       9  ert  rwewer       NaN      NaN   NaN     NaN

# %%
df1.join(df5 , how = 'right')
# Out:
#       name  number test  string     name1  number1 test1 string1
# 1     sudh     4.0  ABC   dsfsf  ineuron1       31  xyz1  dfdsfs
# 0  ineuron     3.0  xyz  dfdsfs     sudh1       41  ABC1   dsfsf
# 6      NaN     NaN  NaN     NaN     krish       61  dyu1  trert1
# 7      NaN     NaN  NaN     NaN     kumar       91  ert1  rwewer

# %%
df1.join(df5 , how = 'left')
# Out:
#       name  number test  string     name1  number1 test1 string1
# 0  ineuron       3  xyz  dfdsfs     sudh1     41.0  ABC1   dsfsf
# 1     sudh       4  ABC   dsfsf  ineuron1     31.0  xyz1  dfdsfs
# 2    krish       6  dyu   trert       NaN      NaN   NaN     NaN
# 3    kumar       9  ert  rwewer       NaN      NaN   NaN     NaN

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is FA55-E833
#
#  Directory of C:\Users\win10\jupyter
#
# 10/31/2021  09:14 PM    <DIR>          .
# 10/31/2021  09:14 PM    <DIR>          ..
# 10/31/2021  08:12 PM    <DIR>          .ipynb_checkpoints
# 10/09/2021  01:59 PM           135,298 1584210047017.docx
# 10/09/2021  01:57 PM           252,512 1584210047017.pdf
# 09/02/2021  09:11 AM            80,633 22nd Aug Assignment.ipynb
# 05/31/2021  07:03 PM    <DIR>          ALBERT-20210531T131400Z-001
# 05/31/2021  06:45 PM        11,796,495 ALBERT-20210531T131400Z-001.zip
# 08/01/2021  07:36 PM    <DIR>          Anamoly-20210801T140417Z-001
# 08/01/2021  07:35 PM        69,348,474 Anamoly-20210801T140417Z-001.zip
# 08/01/2021  07:35 PM        69,348,474 Anamoly-20210801T140418Z-001.zip
# 05/22/2021  04:51 AM    <DIR>          apache-cassandra-3.11.10-bin
# 05/22/2021  04:51 AM    <DIR>          apache-cassandra-3.11.10-bin (1).tar
# 05/22/2021  04:50 AM        38,289,255 apache-cassandra-3.11.10-bin (1).tar.gz
# 05/31/2021  07:03 PM    <DIR>          BERT-20210531T131352Z-001
# 05/31/2021  07:01 PM       824,818,522 BERT-20210531T131352Z-001.zip
# 09/16/2021  09:52 PM               278 books.csv
# 04/13/2021  07:59 PM    <DIR>          captchas
# 05/15/2021  05:57 PM           628,633 carbon_nanotubes.csv
# 05/16/2021  02:30 PM           757,243 CarbonUpdatedFile.csv
# 09/02/2021  08:07 AM            12,584 Casandra Streaming.ipynb
# 09/01/2021  12:17 PM             7,948 Cassandra Streming.ipynb
# 05/19/2021  07:54 PM    <DIR>          Chapter10. ENCODER_DECODER___SEQ2SEQ
# 04/11/2021  06:33 AM    <DIR>          Chapter7. WORD2VEC_CBOW_SKIPGRAM-20210411T005219Z-001
# 04/11/2021  06:24 AM        25,980,599 Chapter7. WORD2VEC_CBOW_SKIPGRAM-20210411T005219Z-001.zip
# 04/17/2021  10:16 AM        25,964,711 Chapter7. WORD2VEC_CBOW_SKIPGRAM-20210417T044431Z-001.zip
# 07/17/2021  09:09 PM    <DIR>          clustering-20210710T141724Z-001
# 05/20/2021  02:58 PM            37,108 Codes-identification-agences-bancaires-FR-4 (9).pdf
# 10/10/2021  11:03 PM    <DIR>          Complete Python Module-20210227T092441Z-001
# 05/31/2021  07:03 PM    <DIR>          DistilBERT-20210531T131340Z-001
# 05/31/2021  06:46 PM       248,797,919 DistilBERT-20210531T131340Z-001.zip
# 05/31/2021  06:54 PM       248,797,918 DistilBERT-20210531T131712Z-001.zip
# 05/19/2021  08:10 AM    <DIR>          DL_Recurrent_Neural_Network 2
# 09/16/2021  09:54 PM             3,155 Untitled22.ipynb
# 10/06/2021  12:57 PM            15,320 Untitled23.ipynb
# 10/10/2021  07:31 PM            53,198 Untitled24.ipynb
# 10/16/2021  01:50 PM            15,570 Untitled25.ipynb
# 10/17/2021  05:20 PM             1,373 Untitled26.ipynb
# 10/25/2021  02:08 PM             1,509 Untitled27.ipynb
# 10/28/2021  04:42 PM             2,136 Untitled28.ipynb
# 10/31/2021  09:14 PM            84,287 Untitled29.ipynb
# 05/20/2021  03:05 PM            15,293 Untitled3.ipynb
# 04/12/2021  12:25 PM            87,701 Untitled39.ipynb
# 05/22/2021  06:18 AM            10,401 Untitled4.ipynb
# 04/12/2021  12:25 PM               555 Untitled40.ipynb
# 04/12/2021  12:25 PM               555 Untitled41.ipynb
# 06/02/2021  07:53 AM             7,971 Untitled5.ipynb
# 06/08/2021  01:14 PM             1,214 Untitled6.ipynb
# 07/04/2021  09:20 AM           300,858 Untitled7.ipynb
# 07/09/2021  08:59 PM               555 Untitled8.ipynb
# 07/10/2021  09:55 AM           199,532 Untitled9.ipynb
# 05/17/2021  10:03 PM    <DIR>          updateddocs-20210516T010855Z-001
# 04/11/2021  11:37 AM    <DIR>          word embedding
#              112 File(s)  4,520,790,040 bytes
#               35 Dir(s)  277,565,014,016 bytes free

# %%
df1 = pd.read_csv('CarbonUpdatedFile.csv')

# %%
df2 = pd.read_csv('locations.csv')

# %%
df2
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# 11  12                3         disabled_parking, elevator, ramp, restroom
# 12  13                3                                                NaN
# 13  14                4                                         wheelchair
# 14  15                4                                         wheelchair
# 15  16                4                                                NaN
# 16  17                4                                         wheelchair
# 17  18                5                           cd, restroom, wheelchair
# 18  19                5                         elevator, ramp, wheelchair
# 19  20                6                                                NaN
# 20  21                7                                 elevator, restroom
# 21  22                8             disabled_parking, restroom, wheelchair
#
#        admin_emails alternate_name  \
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# 5               NaN            NaN
# 6               NaN            NaN
# 7               NaN            NaN
# 8               NaN            NaN
# 9               NaN            NaN
# 10              NaN            NaN
# 11  ohana@gmail.com            NaN
# 12              NaN            NaN
# 13              NaN            NaN
# 14              NaN            NaN
# 15              NaN            NaN
# 16              NaN            NaN
# 17              NaN            NaN
# 18              NaN            NaN
# 19              NaN            NaN
# 20              NaN            NaN
# 21      foo@bar.com  The Test Spot
#
#                                           description             email  \
# 0   A walk-in center for older adults that provide...               NaN
# 1   Provides training and job placement to eligibl...               NaN
# 2   Offers supportive counseling services to San M...               NaN
# 3   Provides supervised visitation services and a ...               NaN
# 4   Provides fixed 8% short term loans to eligible...               NaN
# 5   A multipurpose center offering a wide variety ...               NaN
# 6   Rosener House is a day center for older adults...               NaN
# 7   Delivers a hot meal to the home of persons age...               NaN
# 8   Provides general reading material, including b...               NaN
# 9   Provides general reading and media materials, ...               NaN
# 10  Provides general reading materials, including ...               NaN
# 11  Offers an intergenerational literacy program f...               NaN
# 12  Provides general reading materials, including ...               NaN
# 13  Provides food, clothing, bus tokens and shelte...               NaN
# 14  Provides a long-term (6-12 month) residential ...               NaN
# 15  Provides emergency assistance including food a...               NaN
# 16  Provides emergency food, clothing and furnitur...               NaN
# 17  Provides free medical care to those in need. O...               NaN
# 18  Provides free medical and dental care to those...               NaN
# 19                                           no phone               NaN
# 20                              This is a description               NaN
# 21  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...  info@example.org
#
#                                             languages   latitude   longitude  \
# 0                                    Spanish, Tagalog  37.477227 -122.213221
# 1       Chinese (Mandarin), Tagalog, Italian, Spanish  37.563984 -122.325799
# 2   Chinese (Cantonese), Chinese (Mandarin), Tagal...  37.563984 -122.325799
# 3                                             Spanish  37.563984 -122.325799
# 4                                      Hindi, Spanish  37.563984 -122.325799
# 5                                    Tagalog, Spanish  37.448020 -122.180591
# 6                        Spanish, Tagalog, Vietnamese  37.444178 -122.183093
# 7                                             Spanish  37.448020 -122.180591
# 8                                             Spanish  37.478502 -122.214143
# 9                                             Spanish  37.483842 -122.227395
# 10                                                NaN  37.466553 -122.243090
# 11                                                NaN  37.483842 -122.227395
# 12                                                NaN  37.530423 -122.258643
# 13                                            Spanish  37.491386 -122.231568
# 14                                            Spanish  37.748899 -122.420367
# 15                                             Korean  37.356900 -122.060002
# 16                                                NaN  37.644590 -122.422491
# 17                                            Spanish  37.468614 -122.206798
# 18                                            Spanish  37.532694 -122.293124
# 19                                                NaN        NaN         NaN
# 20                                                NaN  37.529194 -122.287161
# 21    Cantonese, Russian, Spanish, Tagalog, Taiwanese  37.772640 -122.409915
#
#                                    name  \
# 0       Fair Oaks Adult Activity Center
# 1      Second Career Employment Program
# 2                Senior Peer Counseling
# 3              Family Visitation Center
# 4   Economic Self - Sufficiency Program
# 5                          Little House
# 6      Rosener House Adult Day Services
# 7        Meals on Wheels - South County
# 8                      Fair Oaks Branch
# 9                          Main Library
# 10                      Schaberg Branch
# 11                         Project Read
# 12                Redwood Shores Branch
# 13                   Redwood City Corps
# 14          Adult Rehabilitation Center
# 15                      Sunnyvale Corps
# 16    South San Francisco Citadel Corps
# 17     Redwood City Free Medical Clinic
# 18        San Mateo Free Medical Clinic
# 19               Location with no phone
# 20                  Admin Test Location
# 21                     Example Location
#
#                                            short_desc  \
# 0   A multipurpose senior citizens' center serving...
# 1   Provides training and job placement to eligibl...
# 2   Offers supportive counseling services to older...
# 3   Provides supervised visitation services and a ...
# 4              Makes small loans to working families.
# 5             A multipurpose senior citizens' center.
# 6             A day center for adults age 50 or over.
# 7   Will deliver a hot meal to the home of persons...
# 8   Provides general reading materials and referen...
# 9   Provides general reference and reading materia...
# 10  Provides general reading materials and referen...
# 11  Offers an intergenerational literacy program f...
# 12  Provides general reading materials and referen...
# 13  Provides a variety of emergency services to lo...
# 14  Long-term (6-12 month) residential treatment p...
# 15  Provides emergency assistance to persons in im...
# 16  Provides emergency food and clothing and furni...
# 17       Provides free medical care to those in need.
# 18  Provides free medical and dental care to those...
# 19                                           no phone
# 20                        This is a short description
# 21  [NOTE THIS IS NOT A REAL ENTRY--THIS IS FOR TE...
#
#                                        transportation  \
# 0                            SAMTRANS stops in front.
# 1   SAMTRANS stops within 1 block, CALTRAIN stops ...
# 2   Service is provided in person's home or at a m...
# 3   SAMTRANS stops within 1 block, CALTRAIN stops ...
# 4   SAMTRANS stops within 1 block. CALTRAIN stops ...
# 5   SAMTRANS stops within 3 blocks, RediWheels and...
# 6   Transportation can be arranged via Redi-Wheels...
# 7                          Not necessary for service.
# 8                            SAMTRANS stops in front.
# 9   SAMTRANS stops within 1 block; CALTRAIN stops ...
# 10                     SAMTRANS stops within 1 block.
# 11                     SAMTRANS stops within 1 block.
# 12                                                NaN
# 13                             SAMTRANS stops nearby.
# 14          MUNI - 26 Valencia, Mission Street lines.
# 15                         VTA stops within 4 blocks.
# 16  SAMTRANS stops within 1 block, BART stops with...
# 17                    SAMTRANS stops within 2 blocks.
# 18                     SAMTRANS stops within 1 block.
# 19                                                NaN
# 20                    SAMTRANS stops within 1/2 mile.
# 21                      SAMTRANS stops within 1 block
#
#                           website  virtual
# 0                             NaN    False
# 1                             NaN    False
# 2                             NaN    False
# 3                             NaN    False
# 4                             NaN    False
# 5                             NaN    False
# 6                             NaN    False
# 7                             NaN    False
# 8                             NaN    False
# 9                             NaN    False
# 10                            NaN    False
# 11                            NaN    False
# 12                            NaN    False
# 13                            NaN    False
# 14                            NaN    False
# 15                            NaN    False
# 16                            NaN    False
# 17  http://www.samaritanhouse.com    False
# 18  http://www.samaritanhouse.com    False
# 19                            NaN     True
# 20                            NaN    False
# 21         http://www.example.org    False

# %%
df1
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                    2                1                    0,679005
# 1                    2                1                    0,717298
# 2                    2                1                    0,489336
# 3                    2                1                    0,413957
# 4                    2                1                    0,334292
# ...                ...              ...                         ...
# 10716               12                6                    0,834201
# 10717               12                6                    0,698374
# 10718               12                6                    0,923823
# 10719               12                6                    0,934978
# 10720               12                6                    0,953664
#
#       Initial atomic coordinate v Initial atomic coordinate w  \
# 0                        0,701318                    0,017033
# 1                        0,642129                    0,231319
# 2                        0,303751                    0,088462
# 3                        0,632996                    0,040843
# 4                        0,543401                     0,15989
# ...                           ...                         ...
# 10716                    0,399891                     0,89127
# 10717                     0,24471                    0,962699
# 10718                    0,568913                    0,819842
# 10719                    0,602319                    0,938889
# 10720                    0,698374                    0,962699
#
#       Calculated atomic coordinates u' Calculated atomic coordinates v'  \
# 0                             0,721039                         0,730232
# 1                             0,738414                          0,65675
# 2                             0,477676                         0,263221
# 3                             0,408823                         0,657897
# 4                             0,303349                         0,558807
# ...                                ...                              ...
# 10716                         0,841858                         0,405882
# 10717                         0,706555                         0,248416
# 10718                         0,929403                         0,576284
# 10719                         0,941844                         0,610608
# 10720                         0,961243                         0,707812
#
#       Calculated atomic coordinates w'
# 0                             0,017014
# 1                             0,232369
# 2                             0,088712
# 3                             0,039796
# 4                             0,157373
# ...                                ...
# 10716                         0,891356
# 10717                         0,962833
# 10718                         0,819879
# 10719                         0,938755
# 10720                         0,962605
#
# [10721 rows x 8 columns]

# %%
df3 = pd.concat([df1,df2] ,axis= 0)

# %%
df3.to_csv("final.csv")

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is
# 05/31/2021  06:59 PM     1,318,779,810 gpt2-20210531T131332Z-002.zip
# 06/05/2021  05:32 PM             3,763 html_data0.csv
# 06/05/2021  05:32 PM             2,349 html_data1.csv
# 06/05/2021  05:32 PM             3,800 html_data2.csv
# 06/05/2021  05:32 PM             2,619 html_data3.csv
# 06/05/2021  05:32 PM             2,995 html_data4.csv
# 06/05/2021  05:32 PM             2,381 html_data5.csv
# 08/06/2021  10:08 AM            15,763 iNeuron July month update (Responses).xlsx
# 05/31/2021  07:01 PM        43,582,161 INeuron Projects-20210531T132536Z-001.zip
# 10/06/2021  12:51 PM            16,009 iNeuron_july_salary (1).xlsx
# 08/06/2021  11:29 AM            15,966 iNeuron_july_salary.xlsx
# 05/04/2021  10:02 PM            37,006 internship mail id.xlsx
# 08/01/2021  07:45 PM            24,343 Interview questions.ipynb
# 06/05/2021  06:07 PM           119,132 json_dump.csv
# 08/22/2021  02:57 PM    <DIR>          LinearRegression-master
# 05/16/2021  07:51 PM    <DIR>          LinearRegression-master (1) (4)
# 05/08/2021  07:27 PM         2,751,068 LinearRegression-master (1) (4).zip
# 05/20/2021  06:45 AM            18,015 locations.csv
# 10/31/2021  01:10 PM    <DIR>          ML masters
# 04/13/2021  09:58 PM         5,545,096 model_all_architecture_ocr.h5
# 04/13/2021  09:58 PM             5,972 model_ocr.json
# 04/13/2021  09:58 PM         1,855,440 model_weights_ocr.h5
# 06/06/2021  03:19 PM             4,994 my_pickle
# 05/16/2021  04:40 PM           201,836 mysql assignment .ipynb
# 07/11/2021  06:07 PM            59,413 numpy.ipynb
# 04/13/2021  10:11 PM    <DIR>          ocr model
# 04/13/2021  10:11 PM         4,870,396 ocr model.7z
# 04/13/2021  11:12 PM            83,870 OCR Poc.ipynb
# 07/11/2021  09:19 AM           310,434 pandas 3 .ipynb
# 07/18/2021  01:26 PM             2,222 pandas data manipulations  2.ipynb
# 06/06/2021  05:02 PM         1,055,331 Pandas session 1.ipynb
# 07/18/2021  12:31 AM    <DIR>          PCA (4)
# 06/05/2021  05:00 PM             2,658 players_data.csv
# 07/24/2021  05:05 PM         1,113,578 plotly .ipynb
# 09/12/2021  10:50 PM            76,570 python basic 1.ipynb
# 07/07/2021  10:04 PM            14,506 python question discussion .ipynb
# 04/17/2021  08:39 AM    <DIR>          Python-20210417T030818Z-001
# 08/22/2021  08:19 PM            36,882 Rakhi Gift to my sister lastest.xlsx
# 08/22/2021  07:40 PM            42,594 rakhi_gift.xlsx
# 08/22/2021  10:59 PM            46,329 rakhi_new_list.xlsx
# 05/20/2021  02:58 PM            37,108 readpdf.pdf
# 04/25/2021  03:09 PM    <DIR>          Reinforcement learning-20210117T063045Z-001
# 06/06/2021  03:47 PM         2,154,789 Reinforcement learning-20210117T063045Z-001.7z
# 01/17/2021  12:00 PM         2,210,923 Reinforcement learning-20210117T063045Z-001.zip
# 06/05/2021  04:32 PM            31,861 result.csv
# 06/05/2021  04:33 PM            31,778 result1.csv
# 10/31/2021  09:18 PM           135,168 Untitled29.ipynb
# 05/20/2021  03:05 PM            15,293 Untitled3.ipynb
# 04/12/2021  12:25 PM            87,701 Untitled39.ipynb
# 05/22/2021  06:18 AM            10,401 Untitled4.ipynb
# 04/12/2021  12:25 PM               555 Untitled40.ipynb
# 04/12/2021  12:25 PM               555 Untitled41.ipynb
# 06/02/2021  07:53 AM             7,971 Untitled5.ipynb
# 06/08/2021  01:14 PM             1,214 Untitled6.ipynb
# 07/04/2021  09:20 AM           300,858 Untitled7.ipynb
# 07/09/2021  08:59 PM               555 Untitled8.ipynb
# 07/10/2021  09:55 AM           199,532 Untitled9.ipynb
# 05/17/2021  10:03 PM    <DIR>          updateddocs-20210516T010855Z-001
# 04/11/2021  11:37 AM    <DIR>          word embedding
#              113 File(s)  4,521,873,456 bytes
#               35 Dir(s)  277,564,948,480 bytes free

# %%
pwd
# Out:
# 'C:\\Users\\win10\\jupyter'

# %%
dict1 = {'col1' :[1,2,3,4,5,6,7,8,934],
         'col2' :[354,45,54,545,545,545,545,545,234],
         'col3' :"my name is sudhanshu kumar ineuron initelligence private limited".split()
    
}

# %%
df = pd.DataFrame(dict1)

# %%
"my name is sudhanshu kumar".split()
# Out:
# ['my', 'name', 'is', 'sudhanshu', 'kumar']

# %%
df
# Out:
#    col1  col2           col3
# 0     1   354             my
# 1     2    45           name
# 2     3    54             is
# 3     4   545      sudhanshu
# 4     5   545          kumar
# 5     6   545        ineuron
# 6     7   545  initelligence
# 7     8   545        private
# 8   934   234        limited

# %%
df['col4'] = 2*df['col2']

# %%
df
# Out:
#    col1  col2           col3  col4
# 0     1   354             my   708
# 1     2    45           name    90
# 2     3    54             is   108
# 3     4   545      sudhanshu  1090
# 4     5   545          kumar  1090
# 5     6   545        ineuron  1090
# 6     7   545  initelligence  1090
# 7     8   545        private  1090
# 8   934   234        limited   468

# %%
import numpy as np
df['col5'] = np.log(df['col2'])

# %%
df
# Out:
#    col1  col2           col3  col4      col5
# 0     1   354             my   708  5.869297
# 1     2    45           name    90  3.806662
# 2     3    54             is   108  3.988984
# 3     4   545      sudhanshu  1090  6.300786
# 4     5   545          kumar  1090  6.300786
# 5     6   545        ineuron  1090  6.300786
# 6     7   545  initelligence  1090  6.300786
# 7     8   545        private  1090  6.300786
# 8   934   234        limited   468  5.455321

# %%
def testfun(data):
    if data> 500 :
        return np.log10(data)
    else :
        return data/10

# %%
df['col6'] = df['col2'].apply(testfun)

# %%
df
# Out:
#    col1  col2           col3  col4      col5       col6
# 0     1   354             my   708  5.869297  35.400000
# 1     2    45           name    90  3.806662   4.500000
# 2     3    54             is   108  3.988984   5.400000
# 3     4   545      sudhanshu  1090  6.300786   2.736397
# 4     5   545          kumar  1090  6.300786   2.736397
# 5     6   545        ineuron  1090  6.300786   2.736397
# 6     7   545  initelligence  1090  6.300786   2.736397
# 7     8   545        private  1090  6.300786   2.736397
# 8   934   234        limited   468  5.455321  23.400000

# %%
len("my")
# Out:
# 2

# %%
df['col7'] = df['col3'].apply(len)

# %%
df
# Out:
#    col1  col2           col3  col4      col5       col6  col7
# 0     1   354             my   708  5.869297  35.400000     2
# 1     2    45           name    90  3.806662   4.500000     4
# 2     3    54             is   108  3.988984   5.400000     2
# 3     4   545      sudhanshu  1090  6.300786   2.736397     9
# 4     5   545          kumar  1090  6.300786   2.736397     5
# 5     6   545        ineuron  1090  6.300786   2.736397     7
# 6     7   545  initelligence  1090  6.300786   2.736397    13
# 7     8   545        private  1090  6.300786   2.736397     7
# 8   934   234        limited   468  5.455321  23.400000     7

# %%
df.sort_values(by = "col2" ,ascending=False)
# Out:
#    col1  col2           col3  col4      col5       col6  col7
# 3     4   545      sudhanshu  1090  6.300786   2.736397     9
# 4     5   545          kumar  1090  6.300786   2.736397     5
# 5     6   545        ineuron  1090  6.300786   2.736397     7
# 6     7   545  initelligence  1090  6.300786   2.736397    13
# 7     8   545        private  1090  6.300786   2.736397     7
# 0     1   354             my   708  5.869297  35.400000     2
# 8   934   234        limited   468  5.455321  23.400000     7
# 2     3    54             is   108  3.988984   5.400000     2
# 1     2    45           name    90  3.806662   4.500000     4

# %%
l = [1,2,3,4,5,6]

[i+1 for i in l ]
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
def test(data):
    return data +1

# %%
list(map(test,l))
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
def test1 (data):
    if data<3:
        return np.sqrt(data)
    else:
        return np.log(data)

# %%
list(map(test1,l))
# Out:
# [1.0,
#  1.4142135623730951,
#  1.0986122886681098,
#  1.3862943611198906,
#  1.6094379124341003,
#  1.791759469228055]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l1 = [34,45,23,12,34,34]

# %%
list(map(lambda data : data+1 , l))

# %%
list(map(lambda x , y : x+y  , l , l1))
# Out:
# [35, 47, 26, 16, 39, 40]

# %%
def test(x ,y):
    return x+y

# %%
list(map(test , l,l1))
# Out:
# [35, 47, 26, 16, 39, 40]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list(map(lambda x : np.sqrt(x) if x <3 else np.log(x) , l ))
# Out:
# [1.0,
#  1.4142135623730951,
#  1.0986122886681098,
#  1.3862943611198906,
#  1.6094379124341003,
#  1.791759469228055]

# %%
def test1 (data):
    if data<3:
        return np.sqrt(data)
    else:
        return np.log(data)

# %%
import functools

# %%
l1 = [4,5,6,7,7,8,8]

# %%
sum(l1)
# Out:
# 45

# %%
functools.reduce( test1, l1)
# Out:
# 45

# %%
def test1(x,y):
    return x+y

# %%
functools.reduce(lambda x,y : x+y ,l1)
# Out:
# 45

# %%
functools.reduce(lambda x,y : x if x > y else y, l1)
# Out:
# 8

# %%
l1
# Out:
# [4, 5, 6, 7, 7, 8, 8]

# %%
l = [1,2,3,4,5,6,7,7,8,9,9,0,0,0,45,67]

# %%
def test(data):
    if data % 2 ==0:
        return True
    else :
        return False

# %%
4%2
# Out:
# 1

# %%
g = lambda data : True if data % 2 ==0 else False

# %%
list(filter(test, l))
# Out:
# [2, 4, 6, 8, 0, 0, 0]

# %%
list(filter(g , l))
# Out:
# [2, 4, 6, 8, 0, 0, 0]
